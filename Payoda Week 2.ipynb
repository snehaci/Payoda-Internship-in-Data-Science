# %%
#Emoji convertor
def emoji_convertor(msg1):
    emojis={
    ":)":"😊",
    ":(":"😌",
    ";)":"😉",
    ":o":"😮",
    "**":"😃"
    }
    words = msg1.split(" ")
    output = ''
    for word in words:
        output += emojis.get(word,word)+" "
    print(output)

#main    
msg = input(">>>")
emoji_convertor(msg)
# Out:
# >>>good morning :)
# good morning 😊

# %%
try:
    number = int(input("Enter a number to divide 30: "))
    result = 30/number
    print(f"30/{number} = ",result)
except ValueError:
    print("Invalid input!!!")
except ZeroDivisionError:
    print("The number cannot be zero!")
else:
    print("Success")
finally:
    print("Program exits")
# Out:
# Enter a number to divide 30: 0
# The number cannot be zero!
# Program exits

# %%
#Cube root
from scipy.special import cbrt  # import the module
list_1 = [64, 343, 27]            # list
root = cbrt(list_1)                 # use of cbrt() method
n=0

# to get the cube root one by one
for i in root:
    print("The cube root of",list_1[n],":",i)
    n=n+1
# Out:
# The cube root of 64 : 4.0
# The cube root of 343 : 7.0
# The cube root of 27 : 3.0

# %% [markdown]
# # Scipy
#
# #### Scientific Python, well known as Scipy is a numerical processing library in Python. It is well known for several pre-built functions for various mathematical tasks that show up often in Machine Learning.

# %% [markdown]
# # Mathematical Constants
# #### Scipy provides several commonly used Mathematical and Physical Constants.

# %%
from scipy.constants import pi, c, h, G, m_e, Avogadro
print("Pi:", pi)
print("Speed of light:", c)
print("Planck's constant:", h)
print("Newton's Gravitational constant:", G)
print("Mass of electron:", m_e)
print("Avogadro's Number:", Avogadro)
# Out:
# Pi: 3.141592653589793
# Speed of light: 299792458.0
# Planck's constant: 6.62607015e-34
# Newton's Gravitational constant: 6.6743e-11
# Mass of electron: 9.1093837015e-31
# Avogadro's Number: 6.02214076e+23

# %% [markdown]
# #### Scipy also provides several unit values in terms of Standard International (SI) units.

# %%
from scipy.constants import gram, day, inch
print("Grams as kgs:", gram)
print("Day as seconds:", day) 
print("Inch in metres:", inch)
# Out:
# Grams as kgs: 0.001
# Day as seconds: 86400.0
# Inch in metres: 0.0254

# %% [markdown]
# # Matrices and Determinants
#
# #### Scipy provides excellent support for solving multivariate linear equations.

# %%
from scipy import linalg
import numpy as np

A = np.array([[1, -2, 3], [-1, 3, -1], [2, -5, 5]])
B = np.array([9, -6, 17])

X = linalg.solve(A, B)

print("The Solution is:", X)
#The above code represents how Scipy can solve a system of the following 3 linear equations:


#x – 2y + 3z = 9
#-x + 3y – z = -16
#2x – 5y + 5z = 17
# Out:
# The Solution is: [ 1. -1.  2.]

# %% [markdown]
# ### Scipy can find the determinant of several matrices.

# %%
from scipy import linalg
import numpy as np

A = np.array([[1, -2, 3], [-1, 3, -1], [2, -5, 5]])

det = linalg.det(A)

print("The Determinant is:", det)
# Out:
# The Determinant is: 0.9999999999999996

# %%
from scipy import misc, ndimage
import matplotlib.pyplot as plt

image = misc.face()
blurred_image = ndimage.gaussian_filter(image, sigma=10)

plt.imshow(blurred_image)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from scipy import misc, ndimage
import matplotlib.pyplot as plt

image = misc.face()
blurred_image = ndimage.gaussian_filter(image, sigma=10)

plt.imshow(blurred_image)
plt.show()
