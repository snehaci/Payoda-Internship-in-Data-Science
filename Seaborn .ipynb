# %% [markdown]
# # Seaborn
#
# #### Seaborn is a library in Python predominantly used for visualization of the graphical statistical plotting in Python.

# %%
#To initialize the Seaborn library, the command used is:
import seaborn as sns

# %% [markdown]
# ## Using Seaborn we can plot wide varieties of plots like:
# ####    1) Distribution Plots
# ####    2) Pie Chart & Bar Chart
# ####    3) Scatter Plots
# ####    4) Pair Plots

# %%
# Let us access the dataset
import pandas as pd
import numpy as np
pstore = pd.read_csv("googleplaystore.csv")
pstore.head(10)
# Out:
#                       App Category  Rating   Reviews Size       Installs  \
# 0                  ROBLOX     GAME     4.5   4447388   67    100,000,000
# 1          Subway Surfers     GAME     4.5  27722264   76  1,000,000,000
# 2        Candy Crush Saga     GAME     4.4  22426677   74    500,000,000
# 3               Solitaire     GAME     4.7    254258   23     10,000,000
# 4          Bubble Shooter     GAME     4.5    148897   46     10,000,000
# 5  Hello Kitty Nail Salon     GAME     4.2    369203   24     50,000,000
# 6              slither.io     GAME     4.4   5234162  NaN    100,000,000
# 7            Clash Royale     GAME     4.6  23133508   97    100,000,000
# 8            Temple Run 2     GAME     4.3   8118609   62    500,000,000
# 9                     Pou     GAME     4.3  10485308   24    500,000,000
#
#    Type Price Content Rating                        Genres Last Updated  \
# 0  Free     0   Everyone 10+  Adventure;Action & Adventure    31-Jul-18
# ...

# %% [markdown]
# ## 1) Distribution Plots
#
# #### Now, let’s see how distribution plot looks like if we plot for ‘Rating’ column from the above dataset,

# %%
#importing all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Create a distribution plot for rating
sns.distplot(pstore.Rating)
plt.show()
# Out:
# C:\Users\sneha\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Create a distribution plot for rating
sns.distplot(pstore.Rating, bins=20, color="g")
plt.title("Distribution of app ratings", fontsize=20, color = 'red')
plt.show()
# Out:
# C:\Users\sneha\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Adding dark background to the graph
plt.style.use("dark_background")

#Create a distribution plot for rating
sns.distplot(pstore.Rating, bins=20, color="g")
plt.title("Distribution of app ratings", fontsize=20, color = 'red')
plt.show()
# Out:
# C:\Users\sneha\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 2) Pie Chart & Bar Chart
#
# #### Pie Chart is generally used to analyze the data on how a numeric variable changes across different categories.

# %%
#Analyzing the Content Rating column
pstore['Content Rating'].value_counts()
# Out:
# Everyone        608
# Teen            331
# Everyone 10+    131
# Mature 17+       74
# Name: Content Rating, dtype: int64

# %%
#Plotting a pie chart
plt.figure(figsize=[9,7])
pstore['Content Rating'].value_counts().plot.pie()
plt.show()

# %%
#Plotting a bar chart
plt.figure(figsize=[9,7])
pstore['Content Rating'].value_counts().plot.barh()
plt.show()

# %% [markdown]
# ## 3) Scatter Plots
# #### Scatter Plot is used when we want to plot the relationship between any two numeric columns from a dataset. These plots are the most powerful visualization tools that are being used in the field of machine learning.

# %%
# Plotting the same thing now using a jointplot
sns.jointplot(pstore.Size, pstore.Rating)
plt.show()
# Out:
# C:\Users\sneha\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 4) Pair Plots
#
# #### Pair Plots are used when we want to see the relationship pattern among more than 3 different numeric variables.

# %%
# Plotting the same thing now using a jointplot
#importing all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(pstore[['Rating','Reviews']])
plt.show()

# %% [markdown]
# ##### Thank you!
